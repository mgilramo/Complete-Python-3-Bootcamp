# %%
# This top cell should contain the global variables that will be used within the sheet
import random
suits = ('Hearts', 'Diamonds', 'Spades', 'Clubs')
ranks = ("Two", "Three", "Four", "Five", "Six", "Seven", "Eight", "Nine", "Ten", "Jack", "Queen", "King", "Ace")
values = {'Two':2, 'Three':3, 'Four':4, 'Five':5, 'Six':6, 'Seven':7, 'Eight':8,
          'Nine':9, 'Ten':10, 'Jack':11, 'Queen':12, 'King':13, 'Ace':14}

# %% [markdown]
# # Card Class
# The first step will be to create a card class which will require the suit (spades, hearts, etc.) and the value (King, Ace, etc.)

# %%
class Card:
    
    def __init__(self,suit,rank):
        self.suit = suit
        self.rank = rank
        self.value = values[rank]
        
    def __str__(self):
        return '{} of {}'.format(self.rank,self.suit)

# %%
two_hearts = Card('Hearts', 'Two')

# %%
print(two_hearts)
# Out:
# Two of Hearts

# %% [markdown]
# Next step will be to create a dictionary whicih will convert the string rank (e.g., Two) into an integer in order to compare it in the war game

# %%
# Note: this atribute has been pasted at the top of the script as recommended
values = {'Two':2, 'Three':3, 'Four':4, 'Five':5, 'Six':6, 'Seven':7, 'Eight':8,
          'Nine':9, 'Ten':10, 'Jack':11, 'Queen':12, 'King':13, 'Ace':14}

# %%
values[two_hearts.rank]
# Out:
# 2

# %%
three_of_clubs = Card('Clubs', 'Three')

# %%
three_of_clubs.value
# Out:
# 3

# %%
two_hearts.value < three_of_clubs.value
# Out:
# True

# %% [markdown]
# # Deck Class
# After completing the Card class, the next step is to create the deck class

# %%
class Deck:
    
    def __init__(self):
        self.all_cards = []
        
        for suit in suits:
            for rank in ranks:
                # Create the card object
                created_card = Card(suit, rank)
                
                self.all_cards.append(created_card)
                
    def shuffle(self):
        random.shuffle(self.all_cards)
        
    def deal_one(self):
        return self.all_cards.pop()

# %%
new_deck = Deck()

# %%
new_deck.shuffle()

# %%
one_card = new_deck.deal_one()

# %%
print(one_card)
# Out:
# Eight of Hearts

# %%
len(new_deck.all_cards)
# Out:
# 51

# %% [markdown]
# # Player Class
# Finally we will need to create a player class which will have a set of cards

# %%
class Player:
    def __init__(self,name):
        self.name = name
        self.all_cards = []
        
    def remove_one(self):
        return self.all_cards.pop(0)
    
    def add_cards(self,new_cards):
        if type(new_cards) == type([]):
            # List of multiple card objects
            self.all_cards.extend(new_cards)
        else:
            # Single card object
            self.all_cards.append(new_cards)
    
    def __str__(self):
        return f'Player {self.name} has {len(self.all_cards)} cards'

# %%
new_player = Player('Manuel')

# %%
print(new_player)
# Out:
# Player Manuel has 0 cards

# %%
print(one_card)
# Out:
# Eight of Hearts

# %%
new_player.add_cards(one_card)

# %%
print(new_player)
# Out:
# Player Manuel has 1 cards

# %%
print(new_player.all_cards[0])
# Out:
# Eight of Hearts

# %%
new_player.add_cards(one_card)

# %%
print(new_player)
# Out:
# Player Manuel has 2 cards

# %%
print(new_player.all_cards[1])
# Out:
# Eight of Hearts

# %%
list_of_cards = [one_card, one_card, one_card]

# %%
new_player.add_cards(list_of_cards)

# %%
print(new_player)
# Out:
# Player Manuel has 5 cards

# %%
for card in new_player.all_cards:
    print(card)
# Out:
# Eight of Hearts
# Eight of Hearts
# Eight of Hearts
# Eight of Hearts
# Eight of Hearts

# %%
new_player.remove_one()

# %%
print(new_player)
# Out:
# Player Manuel has 4 cards

# %% [markdown]
# # Logic of the Game
# Once all classes have been created, we will start with the game logic

# %%
# Game Setup
def setup_game(player_one_name,player_two_name):
    player_one = Player(player_one_name)
    player_two = Player(player_two_name)

    new_deck = Deck()
    new_deck.shuffle()

    for x in range(26):
        player_one.add_cards(new_deck.deal_one())
        player_two.add_cards(new_deck.deal_one())
        
    return (new_deck, player_one, player_two)

# %%
def play(player_one_name,player_two_name):

    print("Game Setup")
    new_deck, player_one, player_two = setup_game(player_one_name,player_two_name)
        
    game_on = True
    round_num = 0

    while game_on:

        round_num += 1
        print(f'Round {str(round_num)}')
        print(player_one)
        print(player_two)

        if len(player_one.all_cards) == 0:
            print(f'Player {player_one.name}, out of cards! Player {player_two.name} wins!')
            game_on = False
            break

        if len(player_two.all_cards) == 0:
            print(f'Player {player_two.name}, out of cards! Player {player_one.name} wins!')
            game_on = False
            break

        #START A NEW ROUND
        player_one_cards = []
        player_one_cards.append(player_one.remove_one())
        
        player_two_cards = []
        player_two_cards.append(player_two.remove_one())
        
        at_war = True

        while at_war:
            print(f'Player {player_one.name} ({player_one_cards[-1]}) vs. Player {player_two.name} ({player_two_cards[-1]})')
            if player_one_cards[-1].value > player_two_cards[-1].value:
                
                player_one.add_cards(player_one_cards)
                player_one.add_cards(player_two_cards)

                at_war = False
                break

            elif player_one_cards[-1].value < player_two_cards[-1].value:
                
                player_two.add_cards(player_one_cards)
                player_two.add_cards(player_two_cards)
                
                at_war = False
                break

            else:
                print("WAR!")

                if len(player_one.all_cards) < 5:
                    print(f'Player {player_one.name} unable to declare war! Player {player_two.name} wins!')
                    game_on = False
                    break

                elif len(player_two.all_cards) < 5:
                    print(f'Player {player_two.name} unable to declare war! Player {player_one.name} wins!')
                    game_on = False
                    break

                else:
                    for x in range(5):
                        player_one_cards.append(player_one.remove_one())
                        player_two_cards.append(player_two.remove_one())

# %%
play("Manuel","Carmen")
# Out:
# Game Setup
# Round 1
# Player Manuel has 26 cards
# Player Carmen has 26 cards
# Player Manuel (Ten of Diamonds) vs. Player Carmen (Six of Diamonds)
# Round 2
# Player Manuel has 27 cards
# Player Carmen has 25 cards
# Player Manuel (Queen of Spades) vs. Player Carmen (Jack of Hearts)
# Round 3
# Player Manuel has 28 cards
# Player Carmen has 24 cards
# Player Manuel (Queen of Clubs) vs. Player Carmen (Eight of Diamonds)
# Round 4
# Player Manuel has 29 cards
# Player Carmen has 23 cards
# Player Manuel (King of Hearts) vs. Player Carmen (Four of Clubs)
# Round 5
# Player Manuel has 30 cards
# Player Carmen has 22 cards
# Player Manuel (Queen of Hearts) vs. Player Carmen (Three of Diamonds)
# Round 6
# Player Manuel has 31 cards
# Player Carmen has 21 cards
# Player Manuel (Three of Hearts) vs. Player Carmen (Ace of Spades)
# Round 7
# Player Manuel has 30 cards
# Player Carmen has 22 cards
# Player Manuel (Two of Spades) vs. Player Carmen (Jack of Diamonds)
# Round 8
# Player Manuel has 29 cards
# Player Carmen has 23 cards
# Player Manuel (Seven of Hearts) vs. Player Carmen (Two of Diamonds)
# Round 9
# Player Manuel has 30 cards
# Player Carmen has 22 cards
# Player Manuel (Jack of Spades) vs. Player Carmen (King of Diamonds)
# Round 10
# Player Manuel has 29 cards
# Player Carmen has 23 cards
# Player Manuel (Five of Hearts) vs. Player Carmen (King of Clubs)
# Round 11
# Player Manuel has 28 cards
# Player Carmen has 24 cards
# Player Manuel (Four of Spades) vs. Player Carmen (Six of Hearts)
# Round 12
# Player Manuel has 27 cards
# Player Carmen has 25 cards
# Player Manuel (Four of Hearts) vs. Player Carmen (Four of Diamonds)
# WAR!
# Player Manuel (Six of Clubs) vs. Player Carmen (Ace of Hearts)
# Round 13
# Player Manuel has 21 cards
# Player Carmen has 31 cards
# Player Manuel (Three of Spades) vs. Player Carmen (Nine of Spades)
# Round 14
# Player Manuel has 20 cards
# Player Carmen has 32 cards
# Player Manuel (Ace of Clubs) vs. Player Carmen (Seven of Clubs)
# Round 15
# Player Manuel has 21 cards
# Player Carmen has 31 cards
# Player Manuel (Five of Spades) vs. Player Carmen (Seven of Diamonds)
# Round 16
# Player Manuel has 20 cards
# Player Carmen has 32 cards
# Player Manuel (Queen of Diamonds) vs. Player Carmen (Eight of Hearts)
# Round 17
# Player Manuel has 21 cards
# Player Carmen has 31 cards
# Player Manuel (Ten of Clubs) vs. Player Carmen (Ace of Diamonds)
# Round 18
# Player Manuel has 20 cards
# Player Carmen has 32 cards
# Player Manuel (Jack of Clubs) vs. Player Carmen (Nine of Diamonds)
# Round 19
# Player Manuel has 21 cards
# Player Carmen has 31 cards
# Player Manuel (Five of Diamonds) vs. Player Carmen (Three of Clubs)
# Round 20
# Player Manuel has 22 cards
# Player Carmen has 30 cards
# Player Manuel (Two of Clubs) vs. Player Carmen (Five of Clubs)
# Round 21
# Player Manuel has 21 cards
# Player Carmen has 31 cards
# Player Manuel (King of Spades) vs. Player Carmen (Eight of Spades)
# Round 22
# Player Manuel has 22 cards
# Player Carmen has 30 cards
# Player Manuel (Ten of Diamonds) vs. Player Carmen (Three of Hearts)
# Round 23
# Player Manuel has 23 cards
# Player Carmen has 29 cards
# Player Manuel (Six of Diamonds) vs. Player Carmen (Ace of Spades)
# Round 24
# Player Manuel has 22 cards
# Player Carmen has 30 cards
# Player Manuel (Queen of Spades) vs. Player Carmen (
cards
# Player Manuel (Eight of Clubs) vs. Player Carmen (King of Clubs)
# Round 157
# Player Manuel has 42 cards
# Player Carmen has 10 cards
# Player Manuel (Four of Diamonds) vs. Player Carmen (Four of Hearts)
# WAR!
# Player Manuel (Six of Hearts) vs. Player Carmen (Ace of Hearts)
# Round 158
# Player Manuel has 36 cards
# Player Carmen has 16 cards
# Player Manuel (Six of Diamonds) vs. Player Carmen (Five of Clubs)
# Round 159
# Player Manuel has 37 cards
# Player Carmen has 15 cards
# Player Manuel (Two of Diamonds) vs. Player Carmen (King of Diamonds)
# Round 160
# Player Manuel has 36 cards
# Player Carmen has 16 cards
# Player Manuel (Nine of Diamonds) vs. Player Carmen (Eight of Clubs)
# Round 161
# Player Manuel has 37 cards
# Player Carmen has 15 cards
# Player Manuel (Queen of Hearts) vs. Player Carmen (King of Clubs)
# Round 162
# Player Manuel has 36 cards
# Player Carmen has 16 cards
# Player Manuel (Two of Hearts) vs. Player Carmen (Four of Diamonds)
# Round 163
# Player Manuel has 35 cards
# Player Carmen has 17 cards
# Player Manuel (Ace of Spades) vs. Player Carmen (Three of Diamonds)
# Round 164
# Player Manuel has 36 cards
# Player Carmen has 16 cards
# Player Manuel (Seven of Spades) vs. Player Carmen (Queen of Diamonds)
# Round 165
# Player Manuel has 35 cards
# Player Carmen has 17 cards
# Player Manuel (Jack of Clubs) vs. Player Carmen (Nine of Clubs)
# Round 166
# Player Manuel has 36 cards
# Player Carmen has 16 cards
# Player Manuel (Nine of Spades) vs. Player Carmen (Ten of Clubs)
# Round 167
# Player Manuel has 35 cards
# Player Carmen has 17 cards
# Player Manuel (Five of Diamonds) vs. Player Carmen (Six of Hearts)
# Round 168
# Player Manuel has 34 cards
# Player Carmen has 18 cards
# Player Manuel (Queen of Clubs) vs. Player Carmen (Four of Hearts)
# Round 169
# Player Manuel has 35 cards
# Player Carmen has 17 cards
# Player Manuel (Seven of Hearts) vs. Player Carmen (Ace of Clubs)
# Round 170
# Player Manuel has 34 cards
# Player Carmen has 18 cards
# Player Manuel (Ace of Diamonds) vs. Player Carmen (Six of Spades)
# Round 171
# Player Manuel has 35 cards
# Player Carmen has 17 cards
# Player Manuel (Three of Clubs) vs. Player Carmen (Nine of Hearts)
# Round 172
# Player Manuel has 34 cards
# Player Carmen has 18 cards
# Player Manuel (King of Spades) vs. Player Carmen (Two of Clubs)
# Round 173
# Player Manuel has 35 cards
# Player Carmen has 17 cards
# Player Manuel (Eight of Spades) vs. Player Carmen (Ace of Hearts)
# Round 174
# Player Manuel has 34 cards
# Player Carmen has 18 cards
# Player Manuel (Ten of Diamonds) vs. Player Carmen (Two of Diamonds)
# Round 175
# Player Manuel has 35 cards
# Player Carmen has 17 cards
# Player Manuel (Seven of Clubs) vs. Player Carmen (King of Diamonds)
# Round 176
# Player Manuel has 34 cards
# Player Carmen has 18 cards
# Player Manuel (Queen of Spades) vs. Player Carmen (Queen of Hearts)
# WAR!
# Player Manuel (Three of Spades) vs. Player Carmen (Queen of Diamonds)
# Round 177
# Player Manuel has 28 cards
# Player Carmen has 24 cards
# Player Manuel (Eight of Diamonds) vs. Player Carmen (Nine of Spades)
# Round 178
# Player Manuel has 27 cards
# Player Carmen has 25 cards
# Player Manuel (Five of Spades) vs. Player Carmen (Ten of Clubs)
# Round 179
# Player Manuel has 26 cards
# Player Carmen has 26 cards
# Player Manuel (King of Hearts) vs. Player Carmen (Five of Diamonds)
# Round 180
# Player Manuel has 27 cards
# Player Carmen has 25 cards
# Player Manuel (Two of Spades) vs. Player Carmen (Six of Hearts)
# Round 181
# Player Manuel has 26 cards
# Player Carmen has 26 cards
# Player Manuel (Eight of Hearts) vs. Player Carmen (Seven of Hearts)
# Round 182
# Player Manuel has 27 cards
# Player Carmen has 25 cards
# Player Manuel (Seven of Diamonds) vs. Player Carmen (Ace of Clubs)
# Round 183
# Player Manuel has 26 cards
# Player Carmen has 26 cards
# Player Manuel (Jack of Diamonds) vs. Player Carmen (Three of Clubs)
# Round 184
# Player Manuel has 27 cards
# Player Carmen has 25 cards
# Player Manuel (Four of Clubs) vs. Player Carmen (Nine of Hearts)
# Round 185
# Player Manuel has 26 cards
# Player Carmen has 26 cards
# Player Manuel (Six of Clubs) vs. Player Carmen (Eight of Spades)
# Round 186
# Player Manuel has 25 cards
# Player Carmen has 27 cards
# Player Manuel (Five of Hearts) vs. Player Carmen (Ace of Hearts)
# Round 187
# Player Manuel has 24 cards
# Player Carmen has 28 cards
# Player Manuel (Jack of Spades) vs. Player Carmen (Seven of Clubs)
# Round 188
# Player Manuel has 25 cards
# Player Carmen has 27 cards
# Player Manuel (Four of Spades) vs. Player Carmen (King of Diamonds)
# Round 189
# Player Manuel has 24 cards
# Player Carmen has 28 cards
# Player Manuel (Six of Diamonds) vs. Player Carmen (Queen of Spades)
# Round 190
# Player Manuel has 23 cards
# Player Carmen has 29 cards
# Player Manuel (Five of Clubs) vs. Player Carmen (Three of Hearts)
# Round 191
# Player Manuel has 24 cards
# Player Carmen has 28 cards
# Player Manuel (Nine of Diamonds) vs. Player Carmen (Jack of Hearts)
# Round 192
# Player Manuel has 23 cards
# Player Carmen has 29 cards
# Player Manuel (Eight of Clubs) vs. Player Carmen (Ten of Hearts)
# Round 193
# Player Manuel has 22 cards
# Player Carmen has 30 cards
# Player Manuel (Ace of Spades) vs. Player Carmen (Ten of Spades)
# Round 194
# Player Manuel has 23 cards
# Player Carmen has 29 cards
# Player Manuel (Three of Diamonds) vs. Player Carmen (Three of Spades)
# WAR!
# Player Manuel (Ace of Diamonds) vs. Player Carmen (Seven of Spades)
# Round 195
# Player Manuel has 29 cards
# Player Carmen has 23 cards
# Player Manuel (Six of Spades) vs. Player Carmen (Queen of Diamonds)
# Round 196
# Player Manuel has 28 cards
# Player Carmen has 24 cards
# Player Manuel (King of Spades) vs. Player Carmen (Eight of Diamonds)
# Round 197
# Player Manuel has 29 cards
# Player Carmen has 23 cards
# Player Manuel (Two of Clubs) vs. Player Carmen (Nine of Spades)
# Round 198
# Player Manuel has 28 cards
# Player Carmen has 24 cards
# Player Manuel (Ten of Diamonds) vs. Player Carmen (Five of Spades)
# Round 199
# Player Manuel has 29 cards
# Player Carmen has 23 cards
# Player Manuel (Two of Diamonds) vs. Player Carmen (Ten of Clubs)
# Round 200
# Player Manuel has 28 cards
# Player Carmen has 24 cards
# Player Manuel (King of Hearts) vs. Player Carmen (Two of Spades)
# Round 201
# Player Manuel has 29 cards
# Player Carmen has 23 cards
# Player Manuel (Five of Diamonds) vs. Player Carmen (Six of Hearts)
# Round 202
# Player Manuel has 28 cards
# Player Carmen has 24 cards
# Player Manuel (Eight of Hearts) vs. Player Carmen (Seven of Diamonds)
# Round 203
# Player Manuel has 29 cards
# Player Carmen has 23 cards
# Player Manuel (Seven of Hearts) vs. Player Carmen (Ace of Clubs)
# Round 204
# Player Manuel has 28 cards
# Player Carmen has 24 cards
# Player Manuel (Jack of Diamonds) vs. Player Carmen (Four of Clubs)
# Round 205
# Player Manuel has 29 cards
# Player Carmen has 23 cards
# Player Manuel (Three of Clubs) vs. Player Carmen (Nine of Hearts)
# Round 206
# Player Manuel has 28 cards
# Player Carmen has 24 cards
# Player Manuel (Jack of Spades) vs. Player Carmen (Six of Clubs)
# Round 207
# Player Manuel has 29 cards
# Player Carmen has 23 cards
# Player Manuel (Seven of Clubs) vs. Player Carmen (Eight of Spades)
# Round 208
# Player Manuel has 28 cards
# Player Carmen has 24 cards
# Player Manuel (Five of Clubs) vs. Player Carmen (Five of Hearts)
# WAR!
# Player Manuel (Jack of Clubs) vs. Player Carmen (Queen of Spades)
# Round 209
# Player Manuel has 22 cards
# Player Carmen has 30 cards
# Player Manuel (Nine of Clubs) vs. Player Carmen (Nine of Diamonds)
# WAR!
# Player Manuel (Queen of Hearts) vs. Player Carmen (Queen of Diamonds)
# WAR!
# Player Manuel (King of Spades) vs. Player Carmen (Five of Diamonds)
# Round 210
# Player Manuel has 33 cards
# Player Carmen has 19 cards
# Player Manuel (Eight of Diamonds) vs. Player Carmen (Six of Hearts)
# Round 211
# Player Manuel has 34 cards
# Player Carmen has 18 cards
# Player Manuel (Ten of Diamonds) vs. Player Carmen (Seven of Hearts)
# Round 212
# Player Manuel has 35 cards
# Player Carmen has 17 cards
# Player Manuel (Five of Spades) vs. Player Carmen (Ace of Clubs)
# Round 213
# Player Manuel has 34 cards
# Player Carmen has 18 cards
# Player Manuel (King of Hearts) vs. Player Carmen (Three of Clubs)
# Round 214
# Player Manuel has 35 cards
# Player Carmen has 17 cards
# Player Manuel (Two of Spades) vs. Player Carmen (Nine of Hearts)
# Round 215
# Player Manuel has 34 cards
# Player Carmen has 18 cards
# Player Manuel (Eight of Hearts) vs. Player Carmen (Seven of Clubs)
# Round 216
# Player Manuel has 35 cards
# Player Carmen has 17 cards
# Player Manuel (Seven of Diamonds) vs. Player Carmen (Eight of Spades)
# Round 217
# Player Manuel has 34 cards
# Player Carmen has 18 cards
# Player Manuel (Jack of Diamonds) vs. Player Carmen (Five of Clubs)
# Round 218
# Player Manuel has 35 cards
# Player Carmen has 17 cards
# Player Manuel (Four of Clubs) vs. Player Carmen (Three of Hearts)
# Round 219
# Player Manuel has 36 cards
# Player Carmen has 16 cards
# Player Manuel (Jack of Spades) vs. Player Carmen (Ace of Spades)
# Round 220
# Player Manuel has 35 cards
# Player Carmen has 17 cards
# Player Manuel (Six of Clubs) vs. Player Carmen (Ten of Spades)
# Round 221
# Player Manuel has 34 cards
# Player Carmen has 18 cards
# Player Manuel (Nine of Clubs) vs. Player Carmen (Three of Diamonds)
# Round 222
# Player Manuel has 35 cards
# Player Carmen has 17 cards
# Player Manuel (Queen of Clubs) vs. Player Carmen (Jack of Clubs)
# Round 223
# Player Manuel has 36 cards
# Player Carmen has 16 cards
# Player Manuel (Four of Hearts) vs. Player Carmen (Five of Hearts)
# Round 224
# Player Manuel has 35 cards
# Player Carmen has 17 cards
# Player Manuel (Ace of Diamonds) vs. Player Carmen (Ace of Hearts)
# WAR!
# Player Manuel (Four of Diamonds) vs. Player Carmen (Five of Spades)
# Round 225
# Player Manuel has 29 cards
# Player Carmen has 23 cards
# Player Manuel (Seven of Spades) vs. Player Carmen (Ace of Clubs)
# Round 226
# Player Manuel has 28 cards
# Player Carmen has 24 cards
# Player Manuel (King of Spades) vs. Player Carmen (Two of Spades)
# Round 227
# Player Manuel has 29 cards
# Player Carmen has 23 cards
# Player Manuel (Nine of Diamonds) vs. Player Carmen (Nine of Hearts)
# WAR!
# Player Manuel (Queen of Diamonds) vs. Player Carmen (Six of Clubs)
# Round 228
# Player Manuel has 35 cards
# Player Carmen has 17 cards
# Player Manuel (Two of Clubs) vs. Player Carmen (Ten of Spades)
# Round 229
# Player Manuel has 34 cards
# Player Carmen has 18 cards
# Player Manuel (Nine of Spades) vs. Player Carmen (Four of Hearts)
# Round 230
# Player Manuel has 35 cards
# Player Carmen has 17 cards
# Player Manuel (Two of Diamonds) vs. Player Carmen (Five of Hearts)
# Round 231
# Player Manuel has 34 cards
# Player Carmen has 18 cards
# Player Manuel (Ten of Clubs) vs. Player Carmen (Ace of Diamonds)
# Round 232
# Player Manuel has 33 cards
# Player Carmen has 19 cards
# Player Manuel (Five of Diamonds) vs. Player Carmen (Three of Spades)
# Round 233
# Player Manuel has 34 cards
# Player Carmen has 18 cards
# Player Manuel (Eight of Diamonds) vs. Player Carmen (Queen of Hearts)
# Round 234
# Player Manuel has 33 cards
# Player Carmen has 19 cards
# Player Manuel (Six of Hearts) vs. Player Carmen (King of Clubs)
# Round 235
# Player Manuel has 32 cards
# Player Carmen has 20 cards
# Player Manuel (Ten of Diamonds) vs. Player Carmen (Two of Hearts)
# Round 236
# Player Manuel has 33 cards
# Player Carmen has 19 cards
# Player Manuel (Seven of Hearts) vs. Player Carmen (Four of Diamonds)
# Round 237
# Player Manuel has 34 cards
# Player Carmen has 18 cards
# Player Manuel (King of Hearts) vs. Player Carmen (Ace of Hearts)
# Round 238
# Player Manuel has 33 cards
# Player Carmen has 19 cards
# Player Manuel (Three of Clubs) vs. Player Carmen (Four of Spades)
# Round 239
# Player Manuel has 32 cards
# Player Carmen has 20 cards
# Player Manuel (Eight of Hearts) vs. Player Carmen (King of Diamonds)
# Round 240
# Player Manuel has 31 cards
# Player Carmen has 21 cards
# Player Manuel (Seven of Clubs) vs. Player Carmen (Six of Diamonds)
# Round 241
# Player Manuel has 32 cards
# Player Carmen has 20 cards
# Player Manuel (Jack of Diamonds) vs. Player Carmen (Queen of Spades)
# Round 242
# Player Manuel has 31 cards
# Player Carmen has 21 cards
# Player Manuel (Five of Clubs) vs. Player Carmen (Five of Spades)
# WAR!
# Player Manuel (Queen of Clubs) vs. Player Carmen (Two of Diamonds)
# Round 243
# Player Manuel has 37 cards
# Player Carmen has 15 cards
# Player Manuel (Jack of Clubs) vs. Player Carmen (Five of Hearts)
# Round 244
# Player Manuel has 38 cards
# Player Carmen has 14 cards
# Player Manuel (King of Spades) vs. Player Carmen (Ten of Clubs)
# Round 245
# Player Manuel has 39 cards
# Player Carmen has 13 cards
# Player Manuel (Two of Spades) vs. Player Carmen (Ace of Diamonds)
# Round 246
# Player Manuel has 38 cards
# Player Carmen has 14 cards
# Player Manuel (Nine of Diamonds) vs. Player Carmen (Eight of Diamonds)
# Round 247
# Player Manuel has 39 cards
# Player Carmen has 13 cards
# Player Manuel (Jack of Hearts) vs. Player Carmen (Queen of Hearts)
# Round 248
# Player Manuel has 38 cards
# Player Carmen has 14 cards
# Player Manuel (Eight of Clubs) vs. Player Carmen (Six of Hearts)
# Round 249
# Player Manuel has 39 cards
# Player Carmen has 13 cards
# Player Manuel (Ten of Hearts) vs. Player Carmen (King of Clubs)
# Round 250
# Player Manuel has 38 cards
# Player Carmen has 14 cards
# Player Manuel (Six of Spades) vs. Player Carmen (King of Hearts)
# Round 251
# Player Manuel has 37 cards
# Player Carmen has 15 cards
# Player Manuel (Queen of Diamonds) vs. Player Carmen (Ace of Hearts)
# Round 252
# Player Manuel has 36 cards
# Player Carmen has 16 cards
# Player Manuel (Nine of Hearts) vs. Player Carmen (Three of Clubs)
# Round 253
# Player Manuel has 37 cards
# Player Carmen has 15 cards
# Player Manuel (Seven of Diamonds) vs. Player Carmen (Four of Spades)
# Round 254
# Player Manuel has 38 cards
# Player Carmen has 14 cards
# Player Manuel (Eight of Spades) vs. Player Carmen (Eight of Hearts)
# WAR!
# Player Manuel (Four of Hearts) vs. Player Carmen (Ace of Diamonds)
# Round 255
# Player Manuel has 32 cards
# Player Carmen has 20 cards
# Player Manuel (Five of Diamonds) vs. Player Carmen (Jack of Hearts)
# Round 256
# Player Manuel has 31 cards
# Player Carmen has 21 cards
# Player Manuel (Three of Spades) vs. Player Carmen (Queen of Hearts)
# Round 257
# Player Manuel has 30 cards
# Player Carmen has 22 cards
# Player Manuel (Ten of Diamonds) vs. Player Carmen (Ten of Hearts)
# WAR!
# Player Manuel (Six of Diamonds) vs. Player Carmen (Ace of Hearts)
# Round 258
# Player Manuel has 24 cards
# Player Carmen has 28 cards
# Player Manuel (Five of Clubs) vs. Player Carmen (Eight of Spades)
# Round 259
# Player Manuel has 23 cards
# Player Carmen has 29 cards
# Player Manuel (Four of Clubs) vs. Player Carmen (Jack of Spades)
# Round 260
# Player Manuel has 22 cards
# Player Carmen has 30 cards
# Player Manuel (Three of Hearts) vs. Player Carmen (Ace of Spades)
# Round 261
# Player Manuel has 21 cards
# Player Carmen has 31 cards
# Player Manuel (Nine of Clubs) vs. Player Carmen (Six of Clubs)
# Round 262
# Player Manuel has 22 cards
# Player Carmen has 30 cards
# Player Manuel (Three of Diamonds) vs. Player Carmen (Nine of Spades)
# Round 263
# Player Manuel has 21 cards
# Player Carmen has 31 cards
# Player Manuel (Queen of Clubs) vs. Player Carmen (Four of Hearts)
# Round 264
# Player Manuel has 22 cards
# Player Carmen has 30 cards
# Player Manuel (Five of Spades) vs. Player Carmen (Eight of Hearts)
# Round 265
# Player Manuel has 21 cards
# Player Carmen has 31 cards
# Player Manuel (Seven of Spades) vs. Player Carmen (King of Diamonds)
# Round 266
# Player Manuel has 20 cards
# Player Carmen has 32 cards
# Player Manuel (Ace of Clubs) vs. Player Carmen (Jack of Diamonds)
# Round 267
# Player Manuel has 21 cards
# Player Carmen has 31 cards
# Player Manuel (Two of Clubs) vs. Player Carmen (Queen of Spades)
# Round 268
# Player Manuel has 20 cards
# Player Carmen has 32 cards
# Player Manuel (Ten of Spades) vs. Player Carmen (Two of Spades)
# Round 269
# Player Manuel has 21 cards
# Player Carmen has 31 cards
# Player Manuel (Two of Diamonds) vs. Player Carmen (Ace of Diamonds)
# Round 270
# Player Manuel has 20 cards
# Player Carmen has 32 cards
# Player Manuel (Jack of Clubs) vs. Player Carmen (Five of Diamonds)
# Round 271
# Player Manuel has 21 cards
# Player Carmen has 31 cards
# Player Manuel (Five of Hearts) vs. Player Carmen (Jack of Hearts)
# Round 272
# Player Manuel has 20 cards
# Player Carmen has 32 cards
# Player Manuel (King of Spades) vs. Player Carmen (Three of Spades)
# Round 273
# Player Manuel has 21 cards
# Player Carmen has 31 cards
# Player Manuel (Ten of Clubs) vs. Player Carmen (Queen of Hearts)
# Round 274
# Player Manuel has 20 cards
# Player Carmen has 32 cards
# Player Manuel (Nine of Diamonds) vs. Player Carmen (Ten of Diamonds)
# Round 275
# Player Manuel has 19 cards
# Player Carmen has 33 cards
# Player Manuel (Eight of Diamonds) vs. Player Carmen (Two of Hearts)
# Round 276
# Player Manuel has 20 cards
# Player Carmen has 32 cards
# Player Manuel (Eight of Clubs) vs. Player Carmen (Seven of Hearts)
# Round 277
# Player Manuel has 21 cards
# Player Carmen has 31 cards
# Player Manuel (Six of Hearts) vs. Player Carmen (Four of Diamonds)
# Round 278
# Player Manuel has 22 cards
# Player Carmen has 30 cards
# Player Manuel (Nine of Hearts) vs. Player Carmen (Seven of Clubs)
# Round 279
# Player Manuel has 23 cards
# Player Carmen has 29 cards
# Player Manuel (Three of Clubs) vs. Player Carmen (Six of Diamonds)
# Round 280
# Player Manuel has 22 cards
# Player Carmen has 30 cards
# Player Manuel (Seven of Diamonds) vs. Player Carmen (Ten of Hearts)
# Round 281
# Player Manuel has 21 cards
# Player Carmen has 31 cards
# Player Manuel (Four of Spades) vs. Player Carmen (King of Clubs)
# Round 282
# Player Manuel has 20 cards
# Player Carmen has 32 cards
# Player Manuel (Nine of Clubs) vs. Player Carmen (Six of Spades)
# Round 283
# Player Manuel has 21 cards
# Player Carmen has 31 cards
# Player Manuel (Six of Clubs) vs. Player Carmen (King of Hearts)
# Round 284
# Player Manuel has 20 cards
# Player Carmen has 32 cards
# Player Manuel (Queen of Clubs) vs. Player Carmen (Queen of Diamonds)
# WAR!
# Player Manuel (Two of Spades) vs. Player Carmen (Jack of Spades)
# Round 285
# Player Manuel has 14 cards
# Player Carmen has 38 cards
# Player Manuel (Jack of Clubs) vs. Player Carmen (Three of Hearts)
# Round 286
# Player Manuel has 15 cards
# Player Carmen has 37 cards
# Player Manuel (Five of Diamonds) vs. Player Carmen (Ace of Spades)
# Round 287
# Player Manuel has 14 cards
# Player Carmen has 38 cards
# Player Manuel (King of Spades) vs. Player Carmen (Three of Diamonds)
# Round 288
# Player Manuel has 15 cards
# Player Carmen has 37 cards
# Player Manuel (Three of Spades) vs. Player Carmen (Nine of Spades)
# Round 289
# Player Manuel has 14 cards
# Player Carmen has 38 cards
# Player Manuel (Eight of Diamonds) vs. Player Carmen (Five of Spades)
# Round 290
# Player Manuel has 15 cards
# Player Carmen has 37 cards
# Player Manuel (Two of Hearts) vs. Player Carmen (Eight of Hearts)
# Round 291
# Player Manuel has 14 cards
# Player Carmen has 38 cards
# Player Manuel (Eight of Clubs) vs. Player Carmen (Seven of Spades)
# Round 292
# Player Manuel has 15 cards
# Player Carmen has 37 cards
# Player Manuel (Seven of Hearts) vs. Player Carmen (King of Diamonds)
# Round 293
# Player Manuel has 14 cards
# Player Carmen has 38 cards
# Player Manuel (Six of Hearts) vs. Player Carmen (Two of Clubs)
# Round 294
# Player Manuel has 15 cards
# Player Carmen has 37 cards
# Player Manuel (
# Player Manuel has 6 cards
# Player Carmen has 46 cards
# Player Manuel (King of Spades) vs. Player Carmen (Six of Clubs)
# Round 359
# Player Manuel has 7 cards
# Player Carmen has 45 cards
# Player Manuel (Jack of Clubs) vs. Player Carmen (Ace of Spades)
# Round 360
# Player Manuel has 6 cards
# Player Carmen has 46 cards
# Player Manuel (Eight of Clubs) vs. Player Carmen (Four of Hearts)
# Round 361
# Player Manuel has 7 cards
# Player Carmen has 45 cards
# Player Manuel (Seven of Diamonds) vs. Player Carmen (Nine of Spades)
# Round 362
# Player Manuel has 6 cards
# Player Carmen has 46 cards
# Player Manuel (Nine of Hearts) vs. Player Carmen (Two of Spades)
# Round 363
# Player Manuel has 7 cards
# Player Carmen has 45 cards
# Player Manuel (Four of Spades) vs. Player Carmen (King of Diamonds)
# Round 364
# Player Manuel has 6 cards
# Player Carmen has 46 cards
# Player Manuel (King of Spades) vs. Player Carmen (Five of Clubs)
# Round 365
# Player Manuel has 7 cards
# Player Carmen has 45 cards
# Player Manuel (Six of Clubs) vs. Player Carmen (Queen of Spades)
# Round 366
# Player Manuel has 6 cards
# Player Carmen has 46 cards
# Player Manuel (Eight of Clubs) vs. Player Carmen (Six of Hearts)
# Round 367
# Player Manuel has 7 cards
# Player Carmen has 45 cards
# Player Manuel (Four of Hearts) vs. Player Carmen (Seven of Clubs)
# Round 368
# Player Manuel has 6 cards
# Player Carmen has 46 cards
# Player Manuel (Nine of Hearts) vs. Player Carmen (Four of Clubs)
# Round 369
# Player Manuel has 7 cards
# Player Carmen has 45 cards
# Player Manuel (Two of Spades) vs. Player Carmen (Ace of Diamonds)
# Round 370
# Player Manuel has 6 cards
# Player Carmen has 46 cards
# Player Manuel (King of Spades) vs. Player Carmen (Five of Diamonds)
# Round 371
# Player Manuel has 7 cards
# Player Carmen has 45 cards
# Player Manuel (Five of Clubs) vs. Player Carmen (Jack of Hearts)
# Round 372
# Player Manuel has 6 cards
# Player Carmen has 46 cards
# Player Manuel (Eight of Clubs) vs. Player Carmen (Three of Spades)
# Round 373
# Player Manuel has 7 cards
# Player Carmen has 45 cards
# Player Manuel (Six of Hearts) vs. Player Carmen (Queen of Hearts)
# Round 374
# Player Manuel has 6 cards
# Player Carmen has 46 cards
# Player Manuel (Nine of Hearts) vs. Player Carmen (Two of Hearts)
# Round 375
# Player Manuel has 7 cards
# Player Carmen has 45 cards
# Player Manuel (Four of Clubs) vs. Player Carmen (Ten of Diamonds)
# Round 376
# Player Manuel has 6 cards
# Player Carmen has 46 cards
# Player Manuel (King of Spades) vs. Player Carmen (Seven of Hearts)
# Round 377
# Player Manuel has 7 cards
# Player Carmen has 45 cards
# Player Manuel (Five of Diamonds) vs. Player Carmen (Ten of Hearts)
# Round 378
# Player Manuel has 6 cards
# Player Carmen has 46 cards
# Player Manuel (Eight of Clubs) vs. Player Carmen (Four of Diamonds)
# Round 379
# Player Manuel has 7 cards
# Player Carmen has 45 cards
# Player Manuel (Three of Spades) vs. Player Carmen (King of Clubs)
# Round 380
# Player Manuel has 6 cards
# Player Carmen has 46 cards
# Player Manuel (Nine of Hearts) vs. Player Carmen (Six of Spades)
# Round 381
# Player Manuel has 7 cards
# Player Carmen has 45 cards
# Player Manuel (Two of Hearts) vs. Player Carmen (King of Hearts)
# Round 382
# Player Manuel has 6 cards
# Player Carmen has 46 cards
# Player Manuel (King of Spades) vs. Player Carmen (Five of Hearts)
# Round 383
# Player Manuel has 7 cards
# Player Carmen has 45 cards
# Player Manuel (Seven of Hearts) vs. Player Carmen (Nine of Clubs)
# Round 384
# Player Manuel has 6 cards
# Player Carmen has 46 cards
# Player Manuel (Eight of Clubs) vs. Player Carmen (Three of Hearts)
# Round 385
# Player Manuel has 7 cards
# Player Carmen has 45 cards
# Player Manuel (Four of Diamonds) vs. Player Carmen (Queen of Clubs)
# Round 386
# Player Manuel has 6 cards
# Player Carmen has 46 cards
# Player Manuel (Nine of Hearts) vs. Player Carmen (Three of Diamonds)
# Round 387
# Player Manuel has 7 cards
# Player Carmen has 45 cards
# Player Manuel (Six of Spades) vs. Player Carmen (Ace of Clubs)
# Round 388
# Player Manuel has 6 cards
# Player Carmen has 46 cards
# Player Manuel (King of Spades) vs. Player Carmen (Ten of Spades)
# Round 389
# Player Manuel has 7 cards
# Player Carmen has 45 cards
# Player Manuel (Five of Hearts) vs. Player Carmen (Five of Spades)
# WAR!
# Player Manuel (King of Spades) vs. Player Carmen (Ten of Clubs)
# Round 390
# Player Manuel has 13 cards
# Player Carmen has 39 cards
# Player Manuel (Ten of Spades) vs. Player Carmen (Jack of Diamonds)
# Round 391
# Player Manuel has 12 cards
# Player Carmen has 40 cards
# Player Manuel (Five of Hearts) vs. Player Carmen (Eight of Diamonds)
# Round 392
# Player Manuel has 11 cards
# Player Carmen has 41 cards
# Player Manuel (Eight of Clubs) vs. Player Carmen (Queen of Diamonds)
# Round 393
# Player Manuel has 10 cards
# Player Carmen has 42 cards
# Player Manuel (Three of Hearts) vs. Player Carmen (Three of Clubs)
# WAR!
# Player Manuel (Eight of Hearts) vs. Player Carmen (Jack of Spades)
# Round 394
# Player Manuel has 4 cards
# Player Carmen has 48 cards
# Player Manuel (Six of Diamonds) vs. Player Carmen (Jack of Clubs)
# Round 395
# Player Manuel has 3 cards
# Player Carmen has 49 cards
# Player Manuel (Nine of Diamonds) vs. Player Carmen (Ace of Spades)
# Round 396
# Player Manuel has 2 cards
# Player Carmen has 50 cards
# Player Manuel (Seven of Spades) vs. Player Carmen (Seven of Diamonds)
# WAR!
# Player Manuel unable to declare war! Player Carmen wins!
