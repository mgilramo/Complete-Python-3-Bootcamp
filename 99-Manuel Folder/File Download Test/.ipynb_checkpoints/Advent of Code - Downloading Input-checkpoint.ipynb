# %%
import requests

# %%
url = 'https://adventofcode.com/2021/day/3/input'

# %%
cookie = '_ga=GA1.2.1127791646.1648802706; _gid=GA1.2.1391386004.1648802706; session=53616c7465645f5f0e8db9f17434a336118c19b5f4b845d0fa9e7514dd0a6043e26823b924e877eb91dc3cd684385e1eca647f4fa0f8fcd81363e409c5532a51'

# %%
header = {'cookie':cookie}

# %%
r = requests.get(url, headers = header)

# %%
print(r.text)
# Out:
# 111011110101
# 011000111010
# 100000010010
# 000111100110
# 110011111011
# 001100010111
# 011000100100
# 110011111010
# 101011010111
# 010001001011
# 001011011010
# 110001000110
# 011101111111
# 100101010010
# 011010010001
# 010111011110
# 001101101001
# 100000100101
# 011010100101
# 010011010011
# 100000000000
# 001010001000
# 101100110001
# 011010000111
# 011011101101
# 101000011111
# 100010110000
# 101011000010
# 010001100100
# 100100011001
# 111000101110
# 101010111010
# 000111011101
# 011101110101
# 000010101101
# 110110000000
# 111110100101
# 100110101100
# 000001100001
# 101001110010
# 011101100001
# 110111011101
# 000001111001
# 000110110000
# 111001110110
# 101011110101
# 010010011000
# 101011110011
# 011101101110
# 100010000110
# 001000010110
# 110000000100
# 010111101101
# 100000001110
# 111010100101
# 101000000110
# 100001101111
# 000010011010
# 111001000100
# 000100011101
# 000101101001
# 100111110011
# 111011010010
# 110111001010
# 100111111100
# 011011110101
# ...

# %%
with open('input.txt', 'wb') as f:
    f.write(r.content)

# %%
with open('input_nobin.txt', 'w') as f:
    f.write(r.text)

# %%
with open('input_nobin.txt', 'r') as f:
    print(f.read())
# Out:
# 111011110101
# 011000111010
# 100000010010
# 000111100110
# 110011111011
# 001100010111
# 011000100100
# 110011111010
# 101011010111
# 010001001011
# 001011011010
# 110001000110
# 011101111111
# 100101010010
# 011010010001
# 010111011110
# 001101101001
# 100000100101
# 011010100101
# 010011010011
# 100000000000
# 001010001000
# 101100110001
# 011010000111
# 011011101101
# 101000011111
# 100010110000
# 101011000010
# 010001100100
# 100100011001
# 111000101110
# 101010111010
# 000111011101
# 011101110101
# 000010101101
# 110110000000
# 111110100101
# 100110101100
# 000001100001
# 101001110010
# 011101100001
# 110111011101
# 000001111001
# 000110110000
# 111001110110
# 101011110101
# 010010011000
# 101011110011
# 011101101110
# 100010000110
# 001000010110
# 110000000100
# 010111101101
# 100000001110
# 111010100101
# 101000000110
# 100001101111
# 000010011010
# 111001000100
# 000100011101
# 000101101001
# 100111110011
# 111011010010
# 110111001010
# 100111111100
# 011011110101
# ...
