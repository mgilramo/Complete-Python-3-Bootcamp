# %% [markdown]
# # Grabbing a title

# %%
import requests

# %%
result = requests.get("http://www.example.com")

# %%
type(result)
# Out:
# requests.models.Response

# %%
result.text
# Out:
# '<!doctype html>\n<html>\n<head>\n    <title>Example Domain</title>\n\n    <meta charset="utf-8" />\n    <meta http-equiv="Content-type" content="text/html; charset=utf-8" />\n    <meta name="viewport" content="width=device-width, initial-scale=1" />\n    <style type="text/css">\n    body {\n        background-color: #f0f0f2;\n        margin: 0;\n        padding: 0;\n        font-family: -apple-system, system-ui, BlinkMacSystemFont, "Segoe UI", "Open Sans", "Helvetica Neue", Helvetica, Arial, sans-serif;\n        \n    }\n    div {\n        width: 600px;\n        margin: 5em auto;\n        padding: 2em;\n        background-color: #fdfdff;\n        border-radius: 0.5em;\n        box-shadow: 2px 3px 7px 2px rgba(0,0,0,0.02);\n    }\n    a:link, a:visited {\n        color: #38488f;\n        text-decoration: none;\n    }\n    @media (max-width: 700px) {\n        div {\n            margin: 0 auto;\n            width: auto;\n        }\n    }\n    </style>    \n</head>\n\n<body>\n<div>\n    <h1>Example Domain</h1>\n    <p>This domain is for use in illustrative examples in documents. You may use this\n    domain in literature without prior coordination or asking for permission.</p>\n    <p><a href="https://www.iana.org/domains/example">More information...</a></p>\n</div>\n</body>\n</html>\n'

# %%
import bs4

# %%
soup = bs4.BeautifulSoup(result.text,"lxml")

# %%
soup
# Out:
# <!DOCTYPE html>
# <html>
# <head>
# <title>Example Domain</title>
# <meta charset="utf-8"/>
# <meta content="text/html; charset=utf-8" http-equiv="Content-type"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <style type="text/css">
#     body {
#         background-color: #f0f0f2;
#         margin: 0;
#         padding: 0;
#         font-family: -apple-system, system-ui, BlinkMacSystemFont, "Segoe UI", "Open Sans", "Helvetica Neue", Helvetica, Arial, sans-serif;
#
#     }
#     div {
#         width: 600px;
#         margin: 5em auto;
#         padding: 2em;
#         background-color: #fdfdff;
#         border-radius: 0.5em;
#         box-shadow: 2px 3px 7px 2px rgba(0,0,0,0.02);
#     }
#     a:link, a:visited {
#         color: #38488f;
#         text-decoration: none;
#     }
#     @media (max-width: 700px) {
#         div {
#             margin: 0 auto;
#             width: auto;
#         }
#     }
#     </style>
# </head>
# <body>
# <div>
# <h1>Example Domain</h1>
# <p>This domain is for use in illustrative examples in documents. You may use this
#     domain in literature without prior coordination or asking for permission.</p>
# <p><a href="https://www.iana.org/domains/example">More information...</a></p>
# </div>
# </body>
# </html>

# %%
soup.select('title')
# Out:
# [<title>Example Domain</title>]

# %%
soup.select('p')
# Out:
# [<p>This domain is for use in illustrative examples in documents. You may use this
#      domain in literature without prior coordination or asking for permission.</p>,
#  <p><a href="https://www.iana.org/domains/example">More information...</a></p>]

# %%
soup.select('h1')
# Out:
# [<h1>Example Domain</h1>]

# %%
soup.select('title')[0].getText()
# Out:
# 'Example Domain'

# %%
type(soup.select('title')[0])
# Out:
# bs4.element.Tag

# %% [markdown]
# # Grabbing a class

# %%
res = requests.get("https://en.wikipedia.org/wiki/Enzo_Ferrari")

# %%
soup = bs4.BeautifulSoup(res.text,'lxml')

# %%
# soup

# %%
soup.select('.toctext')
# Out:
# [<span class="toctext">Early life</span>,
#  <span class="toctext">Racing career</span>,
#  <span class="toctext">Building Ferrari</span>,
#  <span class="toctext">The Great Walkout</span>,
#  <span class="toctext">Merging with Fiat</span>,
#  <span class="toctext">The Modena Autodrome</span>,
#  <span class="toctext">Final years</span>,
#  <span class="toctext">Racing and management controversies</span>,
#  <span class="toctext">Personal life</span>,
#  <span class="toctext">Death</span>,
#  <span class="toctext">Racing record</span>,
#  <span class="toctext">Grand Prix wins</span>,
#  <span class="toctext">In popular culture</span>,
#  <span class="toctext">See also</span>,
#  <span class="toctext">Notes</span>,
#  <span class="toctext">References</span>,
#  <span class="toctext">External links</span>]

# %%
for item in soup.select('.toctext'):
    # Below 2 lines are the same (.getText() == .text)
    # print(item.getText())
    print(item.text)
# Out:
# Early life
# Racing career
# Building Ferrari
# The Great Walkout
# Merging with Fiat
# The Modena Autodrome
# Final years
# Racing and management controversies
# Personal life
# Death
# Racing record
# Grand Prix wins
# In popular culture
# See also
# Notes
# References
# External links

# %% [markdown]
# # Grabbing an image

# %%
ferrari_p = requests.get("https://en.wikipedia.org/wiki/Ferrari_P#330_P4")

# %%
ferrari_p_bs = bs4.BeautifulSoup(ferrari_p.text,'lxml')

# %%
# ferrari_p_bs

# %%
# ferrari_p_bs.select('img')
# This is not the best approach since it will return 
# all images, including icons, reference images, etc.

# %%
ferrari_p_bs.select('.thumbimage')[8]
# Out:
# <img alt="" class="thumbimage" data-file-height="460" data-file-width="990" decoding="async" height="102" src="//upload.wikimedia.org/wikipedia/commons/thumb/1/13/Ferrari_330_P4_1967.jpg/220px-Ferrari_330_P4_1967.jpg" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/1/13/Ferrari_330_P4_1967.jpg/330px-Ferrari_330_P4_1967.jpg 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/1/13/Ferrari_330_P4_1967.jpg/440px-Ferrari_330_P4_1967.jpg 2x" width="220"/>

# %%
ferrari_p4 = ferrari_p_bs.select('.thumbimage')[8]

# %%
ferrari_p4
# Out:
# <img alt="" class="thumbimage" data-file-height="460" data-file-width="990" decoding="async" height="102" src="//upload.wikimedia.org/wikipedia/commons/thumb/1/13/Ferrari_330_P4_1967.jpg/220px-Ferrari_330_P4_1967.jpg" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/1/13/Ferrari_330_P4_1967.jpg/330px-Ferrari_330_P4_1967.jpg 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/1/13/Ferrari_330_P4_1967.jpg/440px-Ferrari_330_P4_1967.jpg 2x" width="220"/>

# %%
type(ferrari_p4)
# Out:
# bs4.element.Tag

# %%
print(ferrari_p4['src'] == ferrari_p4.get('src'))
print(ferrari_p4['src'])
# Out:
# True
# //upload.wikimedia.org/wikipedia/commons/thumb/1/13/Ferrari_330_P4_1967.jpg/220px-Ferrari_330_P4_1967.jpg

# %% [markdown]
# ##### Images can be included using markdown cells (similar to html) - Example below

# %% [markdown]
# <img src="//upload.wikimedia.org/wikipedia/commons/thumb/1/13/Ferrari_330_P4_1967.jpg/220px-Ferrari_330_P4_1967.jpg">

# %%
ferrari_p4_image_link = requests.get('https:' + ferrari_p4['src'])

# %%
ferrari_p4_image_link.content
# Out:
# b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x01\x00H\x00H\x00\x00\xff\xfe\x00MFile source: http://commons.wikimedia.org/wiki/File:Ferrari_330_P4_1967.jpg\xff\xdb\x00C\x00\x06\x04\x05\x06\x05\x04\x06\x06\x05\x06\x07\x07\x06\x08\n\x10\n\n\t\t\n\x14\x0e\x0f\x0c\x10\x17\x14\x18\x18\x17\x14\x16\x16\x1a\x1d%\x1f\x1a\x1b#\x1c\x16\x16 , #&\')*)\x19\x1f-0-(0%()(\xff\xdb\x00C\x01\x07\x07\x07\n\x08\n\x13\n\n\x13(\x1a\x16\x1a((((((((((((((((((((((((((((((((((((((((((((((((((\xff\xc0\x00\x11\x08\x00f\x00\xdc\x03\x01"\x00\x02\x11\x01\x03\x11\x01\xff\xc4\x00\x1c\x00\x00\x01\x05\x01\x01\x01\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x05\x00\x03\x04\x06\x07\x08\x02\x01\xff\xc4\x00G\x10\x00\x02\x01\x03\x03\x02\x02\x07\x05\x06\x03\x06\x03\t\x00\x00\x01\x02\x03\x04\x05\x11\x00\x12!\x061\x13A\x07\x14"Qaq\x812\x91\xa1\xb1\xd1\x15#3Bb\xc1Rr\x82\x16$%\x92\xa2\xe1\x17CDETcs\x83\x93\xb2\xd2\xe2\xff\xc4\x00\x1a\x01\x00\x02\x03\x01\x01\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x01\x02\x00\x03\x04\x05\x06\xff\xc4\x000\x11\x00\x01\x04\x00\x04\x03\x05\x08\x03\x01\x00\x00\x00\x00\x00\x00\x01\x00\x02\x03\x11\x04\x12!1\x13AQ\x05\x14\x91\xa1\xe1"2aq\x81\xb1\xd1\xf0BRb\xc1\xff\xda\x00\x0c\x03\x01\x00\x02\x11\x03\x11\x00?\x00\xb5\xd5\x8f\x0f\xad\xfd,\xcf\xb6.\x0c 3>\x1b\x8a8\xce>Z\xe6\x18\xe3\x7f\x0c`\xb8\xe3\xc8g]+\xd5t\xae/>\x94\xee\x01\x19\x9a9\x91c\x00)\r\x8a8N\x08\xc6O}ssI(9\x91V7\'\x94\xf0\x95~\x98\xc6\x8b7(/(\xac\xb3\xa9\x93v\xd1\xc9\xdc3\x8d70\xdf+\xb2v\'\xb7\xbbN;\xb0\x05\xb6(\x07\xb6Pk\xc0\x99\x89\xe1\x13\xe5\x83\xfa\xe9\xabU-\x15\xe9X\x0c\xd7-\x9e3F\xa26c\x87+\x93\xf4\xd4\x08f"\xe6\xab%O\xee\x8c\x9c\xb3&\xe1\xdf\xdd\xa2\xdd++\x9a\xd9\xd9Y\x13d$\xf3\x9f\x7f\xc7:\x85A\xeau\x88\xefSX\xd4\xf5\xc8\xe0\xa2\xba\x12\x92\x8c\xf6\x0c;\x1f\x9f\x1aC@\x94u\xa5c\xf4\x89<\xd1T[V\t\xa6\x0b\xea\xe0\x9f\xb4\xaax\x1c\x81\xaah\xac\x9c6\xe13\x97\xf7\x93\xce\xad\x9d\x7f)\xf5\xcb|e\xa4p\xb4\xcaq\x9d\x98\xed\xee\xef\xaa\x93\xca\xa1\x8e\xd8\xe4\x1e\x7f\xc5<\xfe\x1a-\x02\x90\xb2\x9c[\x85H\x19\xf1C\x1f-\xd1\xa9\xfc\xc6\xa5S\xdekR3\x13N\xc6\x99\x8f1\x00\x02g\xfc\xbd\xbf\r7\nS\x1a\xbad\x9aYV)]U\xdf \xed\x04\x81\x9cy\xe3Z\x8c\xbe\x86\xdd\x9fu/PF\xb1\xb7o\x12\x8f<}\x0e\xb3\xcd\x88\x86\x1a\xe2\x1a\xbf\x82\xb9\x8c\x91\xde\xea\xcc\x7fkU.|9#Q\x9e\x00L\x11\xf7\x11\xa9\xb4w\x8b\x9cq\xc8\xc6\xba\x7f\r\x14\xb6\x05T\xc8A\xc7a\x86\xd5\xe6_C\xb7\x04e\x0b{\xb7\xfc\xda\x07P~\xfd<=\x14^\xa3\xa6\x96\x11]mp\xfd\x9bl\x9f\xfe\xba\xa4\xe3p\xc7g\x04\xfc\x19z*T\x9dGy\xa4\xa2\x89\xe2\xb8\\"\xf1\x0e\xed\xc2\xb2C\x9f\x9eO?]9/U\xd6U\xb2IW\x02K \x18f\x0f\xb7\xc4\xf8\x9fg\xbf\xc7V\xda\x8fF\x97\xafU\x82!5\x9d\x9e1\x82^vO\xcdt?\xff\x00\no\xf9,\x92Z\x08\xff\x00\n\xd5\x03\x9f\xcbQ\xb8\x9c1\xdd\xc1B\xc9F\xc0\xa1\x16\xcb\x81\xa9\xb8Q\x95\x87\xc1\x8cJ\x01\\\xab\xe4\xfc\x0e\xc0\x7f\x1d\x15\xea{\xbd:u\x05Ah\xa4b\xaa2\xec\x91\x12~\x00\x14\xce\x8aY}\x1cu\x15\x1d]#\xb44\xad\x1cN\x18\x95\xa8\x1f\x80\xd3\x97oG\xbdCp\xbdTT5\xbe\x17\x8d\xc6\xd8\xd8\xce\xb9\x1cw9:\'\x11\x87;8x\xa0\x19%\xdd#wI\xe8b\xf4\x1bo\x9a\xae\x86oW\x9eD;v\xa99.Nv\xe4\x01\xdb\xcbY\xe5%m\x94H\x82\n*\xa1!>\xc8Kps\xf4\xfd\xee\xb4\xbe\xa0\xe9\xdb\x9c\xfe\x8em6\x18\xa8$\x92\xae\x92Ty\x02L\xa5N\xdc\x9e2~:\xcfj:7\xab)\xa72\xc3j\xad\x8d\x81\xf6v\x15$}\xc4\xe9\x9b4.\xbflx\x842\xbc\r\xbc\x94\xa4\xea\x1blTS\xdbg\xa6\xc4\r\xc9iml%\x07\xe3\xed\xf1\xf3\xd0z/\xd8\x9e\x0b\x89\xc8H\t\xc2\x95\xf1I\xfc9\x1azN\x8d\xea\xa6\x8d\xa5\xa8\xb4\\d\x0cr[\xc2\xdcI\xfc\xf4\xcc\xdd-y\x8a\x8dD\x96{\x9e3\x9c-#\xe4i\xf3G\xc9\xdea\x00\x1d\xccy)p\xc7\xd2a\x80z\x8d\xa4\x1f\xb4\xcd8\x07\xee\\\xea|\x96\xee\x9c\x86\x9d\x8c\x17\x14\x8d[\x91\x89\xe6R~D\xc7\xf9\xea\xb0l\xb5\xd0\x91\xbe\xdf\\\xb89\xf6\xa9\xdb\x8d;#\xd6\xc8\xca\x92B\xe0\x8e\x14x\x0c\x08\xfb\x86\x9c\x00\x7f\x91B\xcfE`\x9a\xc7a!R\x9a\xf0\x8e\xc4g\xf8\xde\x1b/\xdf\x1f:/\xd0\x94\xf4\xf47\x1a\x91\x05b8d9V\x9a7v\xe0\xf2=\x90\x7f-R\x16:\xd8$,\xf4\xee\xacG\xf3\xc2\xff\x00\xa6\xac=\x12\xd3=\xdaB\xec#R\x87\x9c2\xff\x00m\x07\n\x1b\xa9\x98\xf4Fk:u\xd1%\xb8-\xc6\xb28e\x90\xb0z\x85XQ~NN\x0e\xa2\nI$`\x89\xd4/\x0b\x81\xc6\xda\xd8\x8a\xb7\xd4J4\xc5\xf ...

# %%
# NOTE: the file format should be the same as the one within the original link
with open('ferrari_p4.jpg', 'wb') as f:
    f.write(ferrari_p4_image_link.content)
